# %%
import time

# %%
def solution(S):
    
    if len(S)<2:
        return S
    sChar = []
    for char in S:
        sChar.append(char)
    trans = True
    while trans:
        trans = False
        i=0
        while i <(len(sChar)-1):
            if sChar[i]+sChar[i+1] in ["AB","BA","CD","DC"]:
                del(sChar[i+1])
                del(sChar[i])
                trans = True
            i+=1
    return "".join(sChar)
tic = time.perf_counter()
solution("...")
toc = time.perf_counter()
print(f"It took {toc - tic:0.4f} seconds")
print(solution("CABCABDA"))
# Out:
# It took 0.0323 seconds
# CA

# %%
def solution2(S):
    # write your code in Python 3.6
    if len(S)<2:
        return S
    sChar = []
    bufferList = []
    for char in S:
        sChar.append(char)
    trans = True
    while trans:
        trans = False
        bufferList = []
        i=0
        while i <(len(sChar)):
            if i <(len(sChar)-1) and sChar[i]+sChar[i+1] in ["AB","BA","CD","DC"]:
                i +=2
                trans = True
            else:
                bufferList.append(sChar[i])
                i+=1
        sChar = bufferList
    return "".join(sChar)
tic = time.perf_counter()
solution2("...")
toc = time.perf_counter()
print(f"It took {toc - tic:0.4f} seconds")

print(solution2("CABCABDA"))
# Out:
# It took 0.0223 seconds
# CA

# %%
def solution3(S):
    # write your code in Python 3.6
    if len(S)<2:
        return S
    sChar = []
    bufferList = []
    for char in S:
        sChar.append(char)
    i=0
    while i <len(sChar)-1:
        if sChar[i]+sChar[i+1] in ["AB","BA","CD","DC"]:
            del(sChar[i+1])
            del(sChar[i])
            if i>0:
                i-=1
        else:
            i+=1
    return "".join(sChar)
tic = time.perf_counter()
solution3("...")
toc = time.perf_counter()
print(f"It took {toc - tic:0.4f} seconds")

print(solution3("CABCABDA"))
# Out:
# It took 0.0301 seconds
# CA
